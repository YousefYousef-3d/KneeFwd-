# %% [markdown]
# # Demo simulator notebook
#
# This notebook is intentionally not executed in the repository. Run cells from top to bottom after installing dependencies.

# %%
from pathlib import Path
import sys
PROJECT_ROOT = Path.cwd().resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
from src.simulate_recovery import run_simulation
from src.validation import run_validation

# %% [markdown]
# ## Run simulation
# Uncomment the next line to generate local outputs.

# %%
# results = run_simulation('config/default_config.yaml')

# %% [markdown]
# ## Validate outputs
# Run after generating outputs.

# %%
# validation_metrics = run_validation('config/default_config.yaml')
# validation_metrics.head()
